# %%
from low_pass_filter import LPF
from IPython.display import display
from matplotlib import pyplot as plt
from PIL import Image
import numpy as np

# %%
image_name = "test.jpg"
im = Image.open(image_name)
im = np.array(im)
img = Image.fromarray(im, 'RGB')
display(img)

filtered_image = LPF(image_name, size=3, rgb=True)
img = Image.fromarray(filtered_image, 'RGB')
display(img)

filtered_image = LPF(image_name, size=5, rgb=True)
img = Image.fromarray(filtered_image, 'RGB')
display(img)

filtered_image = LPF(image_name, size=7, rgb=True)
img = Image.fromarray(filtered_image, 'RGB')
display(img)

filtered_image = LPF(image_name, size=9, rgb=True)
img = Image.fromarray(filtered_image, 'RGB')
display(img)

filtered_image = LPF(image_name, size=11, rgb=True)
img = Image.fromarray(filtered_image, 'RGB')
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x389>
# <PIL.Image.Image image mode=RGB size=600x389>
# <PIL.Image.Image image mode=RGB size=600x389>
# <PIL.Image.Image image mode=RGB size=600x389>
# <PIL.Image.Image image mode=RGB size=600x389>
# <PIL.Image.Image image mode=RGB size=600x389>
